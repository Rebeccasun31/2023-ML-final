# %% [markdown]
# To run my inference code on Colab, I put it in my GitHub repo (with my training codes).
#
# Also, I download the dataset and weight from my Google drive automatically.
#
# Therefore, You can just press **"run all"** and get the result!
#
# The output will be saved as 'content/2023-ML-final/output.csv'

# %%
# !git clone https://github.com/Rebeccasun31/2023-ML-final.git
# %cd 2023-ML-final
# Out:
# Cloning into '2023-ML-final'...
# remote: Enumerating objects: 12899, done.
# remote: Counting objects: 100% (87/87), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 12899 (delta 52), reused 53 (delta 24), pack-reused 12812
# Receiving objects: 100% (12899/12899), 352.44 MiB | 28.29 MiB/s, done.
# Resolving deltas: 100% (76/76), done.
# /content/2023-ML-final

# %%
import gdown
import os

# download dataset
# !gdown 'https://drive.google.com/uc?id=1A78YVY2JTE1oytBx8Ebvd4ERWF0RqPa0' -O './training/dataset.zip'
# !unzip './training/dataset.zip' -d './training/'
os.remove('./training/dataset.zip')

# download weight
# !gdown 'https://drive.google.com/uc?id=161Z0WuOI3aOOLviPViJzXK644beJw4c3'
# !unzip '110550034_weight.zip'
os.remove('110550034_weight.zip')
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#   inflating: ./training/dataset/train/131.Vesper_Sparrow/as5e31zuu7l1vvc2.jpg
#   inflating: ./training/dataset/train/131.Vesper_Sparrow/e7o15dzvytuwon7h.jpg
#   inflating: ./training/dataset/train/131.Vesper_Sparrow/f7hwzv89j9adt8vx.jpg
#   inflating: ./training/dataset/train/131.Vesper_Sparrow/i6v5nc13mv88pg9z.jpg
#   inflating: ./training/dataset/train/131.Vesper_Sparrow/id1ll2725zqq25b0.jpg
#   inflating: ./training/dataset/train/131.Vesper_Sparrow/isa1e7215ybst2q4.jpg
#   inflating: ./training/dataset/train/131.Vesper_Sparrow/iz2nn8llqoftaknn.jpg
#   inflating: ./training/dataset/train/131.Vesper_Sparrow/jnr856v8oq3tx40k.jpg
#   inflating: ./training/dataset/train/131.Vesper_Sparrow/jqr9cli8cpeig4v0.jpg
#   inflating: ./training/dataset/train/131.Vesper_Sparrow/o0q4fmrdl3g6dzsf.jpg
#   inflating: ./training/dataset/train/131.Vesper_Sparrow/onqfy86pgjsxt2g7.jpg
#   inflating: ./training/dataset/train/131.Vesper_Sparrow/oqn80owlje5m1bl2.jpg
# ...

# %%
# %cd training
# !python inference.py -pr ../110550034_weight -ir ./dataset/test
# %cd ..
# Out:
# /content/2023-ML-final/training
# Downloading: "https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_large_patch4_window12_384_22k.pth" to /root/.cache/torch/hub/checkpoints/swin_large_patch4_window12_384_22k.pth
# test: 2000 images
# ['01pqvgnpo4kj20uc', '011.Rusty_Blackbird']
# ['01txr2cjmqt2mac3', '124.Le_Conte_Sparrow']
# ['01v6lr17lljyjrsb', '035.Purple_Finch']
# ['01yn4elsxm9vxfrj', '078.Gray_Kingbird']
# ['0390nt45sljdiv3o', '168.Kentucky_Warbler']
# ['03m0wf598v4upr9t', '092.Nighthawk']
# ['04gjm07ey91fw4ic', '074.Florida_Jay']
# ['04x6l4edzt2srb0q', '183.Northern_Waterthrush']
# ['05hfh9g43e8ytj7a', '191.Red_headed_Woodpecker']
# ['06l9qcrov5g6rs00', '088.Western_Meadowlark']
# ['078e1vsyg5n6rgcx', '138.Tree_Swallow']
# ['07fvjtkaw3tupkh7', '089.Hooded_Merganser']
# ['07ojk47mton7kbyu', '129.Song_Sparrow']
# ['09qx77jzhzooaae5', '163.Cape_May_Warbler']
# ['0a4zq08pju2gkwcs', '003.Sooty_Albatross']
# ['0arocb5hdkgqyle5', '004.Groove_billed_Ani']
# ...
