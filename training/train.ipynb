# %%
# !pip install wandb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 14.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 14.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 18.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip '/content/drive/MyDrive/ML_final/FGCV-HERBS.zip' -d '/content/'
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#   inflating: /content/FGVC-HERBS/dataset/train/092.Nighthawk/ai2c3fxhbjnvowja.jpg
#   inflating: /content/FGVC-HERBS/dataset/train/092.Nighthawk/apuny3m5q52pn1c6.jpg
#   inflating: /content/FGVC-HERBS/dataset/train/092.Nighthawk/aqmifqq2c6dmptsl.jpg
#   inflating: /content/FGVC-HERBS/dataset/train/092.Nighthawk/av1yu0eatr4c13g5.jpg
#   inflating: /content/FGVC-HERBS/dataset/train/092.Nighthawk/baqfng5hyr3dqfdu.jpg
#   inflating: /content/FGVC-HERBS/dataset/train/092.Nighthawk/d1eh10zwnjsmsppv.jpg
#   inflating: /content/FGVC-HERBS/dataset/train/092.Nighthawk/dzgbwikrxzdzvtlo.jpg
#   inflating: /content/FGVC-HERBS/dataset/train/092.Nighthawk/f0o0hgppdj8i0vnw.jpg
#   inflating: /content/FGVC-HERBS/dataset/train/092.Nighthawk/g4i1p5pau3p6mri3.jpg
#   inflating: /content/FGVC-HERBS/dataset/train/092.Nighthawk/i6j9awjrwtd36ahs.jpg
#   inflating: /content/FGVC-HERBS/dataset/train/092.Nighthawk/jra8h84128xp4vjm.jpg
# ...

# %%
# %cd /content/FGVC-HERBS
# Out:
# /content/FGVC-HERBS

# %%
import wandb
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# !python main.py --c ./configs/config.yaml
# Out:
# Reading Config.......[success][0.0104 sceonds]
# Setting Environment...
# Building Dataloader....[dataset] class number: 200
# [dataset] class number: 200
#     Train Samples: 7834 (batch: 980)
#     Validation Samples: 1954 (batch: 245)
# ....[success][0.0158 sceonds]
# Downloading: "https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_large_patch4_window12_384_22k.pth" to /root/.cache/torch/hub/checkpoints/swin_large_patch4_window12_384_22k.pth
# Building Model....Building...
# ....[success][10.3484 sceonds]
# Building Optimizer........[success][0.0019 sceonds]
# wandb: Currently logged in as: rebeccasun31. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.1
# wandb: Run data is saved locally in /content/FGVC-HERBS/wandb/run-20231228_182112-9yapi0sr
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run basline
# wandb: ⭐️ View project at https://wandb.ai/rebeccasun31/FGVC-HERBS
# ...

# %%
import shutil
import os

source = '/content/FGVC-HERBS'

des = '/content/drive/MyDrive/ML_final/training/'

shutil.copytree(source, des)
# Out:
# '/content/drive/MyDrive/ML_final/training/'
